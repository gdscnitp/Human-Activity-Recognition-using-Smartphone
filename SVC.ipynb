# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Load The Datasets(Train and Test)

# %%
train_df=pd.read_csv("/content/drive/MyDrive/train.csv")

# %%
train_df.head()
# Out:
#           0         1         2  ...       560  Subject  activity
# 0  0.288585 -0.020294 -0.132905  ... -0.058627        1         5
# 1  0.278419 -0.016411 -0.123520  ... -0.054317        1         5
# 2  0.279653 -0.019467 -0.113462  ... -0.049118        1         5
# 3  0.279174 -0.026201 -0.123283  ... -0.047663        1         5
# 4  0.276629 -0.016570 -0.115362  ... -0.043892        1         5
#
# [5 rows x 563 columns]

# %%
test_df=pd.read_csv("/content/drive/MyDrive/test.csv")

# %%
test_df.head()
# Out:
#           0         1         2  ...       560  Subject  activity
# 0  0.257178 -0.023285 -0.014654  ... -0.057978        2         5
# 1  0.286027 -0.013163 -0.119083  ... -0.083898        2         5
# 2  0.275485 -0.026050 -0.118152  ... -0.079346        2         5
# 3  0.270298 -0.032614 -0.117520  ... -0.077108        2         5
# 4  0.274833 -0.027848 -0.129527  ... -0.073857        2         5
#
# [5 rows x 563 columns]

# %% [markdown]
# Prepare the Datasets!

# %%
from sklearn.model_selection import train_test_split
x=train_df.drop('activity',axis=1)
y=train_df['activity']
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.30)

# %%
X_train
# Out:
#              0         1         2  ...       559       560  Subject
# 736   0.280495 -0.018677 -0.112435  ...  0.044667 -0.064115        5
# 4030  0.275488 -0.014069 -0.115585  ...  0.107072  0.196253       21
# 1614  0.286186 -0.049947 -0.117113  ...  0.291679  0.248189        7
# 6313  0.275877 -0.019070 -0.134976  ...  0.229476  0.053515       28
# 1438  0.251897 -0.028068 -0.128998  ...  0.164220  0.235111        7
# ...        ...       ...       ...  ...       ...       ...      ...
# 2011  0.284566  0.039980 -0.212988  ...  0.217311 -0.126092       11
# 6014  0.243983 -0.006365 -0.093235  ...  0.190619  0.042610       27
# 1639  0.280025 -0.016467 -0.099707  ...  0.197941  0.059498        8
# 792   0.263040 -0.025308 -0.129129  ...  0.116526  0.031875        5
# 1180  0.276273 -0.017159 -0.110358  ...  0.269212  0.171500        6
#
# [5146 rows x 562 columns]

# %%
X_test
# Out:
#              0         1         2  ...       559       560  Subject
# 428   0.292282 -0.014278 -0.119158  ... -0.660746 -0.323425        3
# 4645  0.280530 -0.058808 -0.056033  ...  0.277068  0.070721       22
# 7248  0.312154 -0.030909 -0.070177  ... -0.574308 -0.429702       30
# 2413  0.212681 -0.017124 -0.124006  ...  0.044709 -0.048157       14
# 3503  0.285945 -0.009377 -0.127710  ... -0.530527 -0.441404       17
# ...        ...       ...       ...  ...       ...       ...      ...
# 1258  0.258596  0.048193 -0.130578  ...  0.258794 -0.005568        6
# 1685  0.277076 -0.018039 -0.104205  ... -0.730349 -0.257667        8
# 6056  0.280678 -0.012590 -0.101437  ...  0.224780  0.035982       27
# 1254  0.194793  0.002425 -0.096793  ...  0.242320 -0.003479        6
# 817   0.225295 -0.060228 -0.108575  ...  0.095596  0.021744        5
#
# [2206 rows x 562 columns]

# %% [markdown]
# Visualisation of Dataset

# %%
X_train.shape
# Out:
# (5146, 562)

# %%
y_train.shape
# Out:
# (5146,)

# %%
X_test.shape
# Out:
# (2206, 562)

# %%
y_test.shape
# Out:
# (2206,)

# %% [markdown]
# # SVC Model

# %%
from sklearn import svm

# %%
model = svm.SVC(kernel='rbf')
model.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
model.score(X_train, y_train)
# Out:
# 0.9514185775359503

# %%
pred=model.predict(X_test)

# %% [markdown]
# Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, pred)

# %%
print(accuracy)
# Out:
# 0.9342701722574795

# %% [markdown]
# Classification Report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.98      1.00      0.99       361
#            2       0.98      0.96      0.97       325
#            3       0.98      0.99      0.98       291
#            4       0.88      0.79      0.83       399
#            5       0.82      0.89      0.86       408
#            6       0.99      1.00      1.00       422
#
#     accuracy                           0.93      2206
#    macro avg       0.94      0.94      0.94      2206
# weighted avg       0.93      0.93      0.93      2206

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, pred)
# Out:
# array([[360,   1,   0,   0,   0,   0],
#        [  8, 312,   5,   0,   0,   0],
#        [  0,   4, 287,   0,   0,   0],
#        [  0,   0,   0, 317,  78,   4],
#        [  0,   0,   0,  45, 363,   0],
#        [  0,   0,   0,   0,   0, 422]])

# %% [markdown]
# F1 Score

# %%
from sklearn.metrics import f1_score
f1_score(y_test, pred, average='macro')
# Out:
# 0.9379500936754428

# %% [markdown]
# Saving the Model

# %%
import pickle

# %%
pickle.dump(model,open("model_svc.pkl","wb+"),protocol=pickle.HIGHEST_PROTOCOL)
